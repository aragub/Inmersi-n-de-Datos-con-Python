# %% [markdown]
# <a href="https://colab.research.google.com/github/sheilidi/Inmersi-n-de-Datos-con-Python/blob/main/Clase%2003%20_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1

# %% [markdown]
# Bienvenido a nuestro primer ecuentro de inmersion de datos

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmuebles = pd.read_csv ("/content/inmuebles_bogota.csv")

inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {"Baños":"Banos", "Área": "Area"}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                        Descripcion  \
# 9302         Casa                              Casa en venta en Niza
# 4449  Apartamento                       Apartamento en venta en Suba
# 9206  Apartamento                   Apartamento en venta en Cedritos
# 6185  Apartamento                    Apartamento en venta en Usaquén
# 2191         Casa  Casa en venta en Cundinamarca - Bogotá D.C. - ...
# 2461  Apartamento                   Apartamento en venta en Fontibón
# 2752  Apartamento                    Apartamento en venta en Usaquén
# 8108         Casa                     Casa en venta en Puente Aranda
# 4195  Apartamento                       Apartamento en venta en Bosa
# 8157  Apartamento                    Apartamento en venta en Usaquén
#
#       Habitaciones  Banos  Area              Barrio  \
# 9302             5      3   230                Niza
# 4449             3      2    55                Suba
# 9206             3      3   128            Cedritos
# 6185             1      2    66             Usaquén
# 2191             3      3    85  Zona Noroccidental
# 2461             3      1    44            Fontibón
# 2752             1      2    51             Usaquén
# 8108             6      3   222       Puente Aranda
# 4195             2      1    43                Bosa
# 8157             3      2    57             Usaquén
#
#                                                  UPZ          Valor
# 9302                                            Niza  $ 630.000.000
# 4449                                            Suba  $ 240.000.000
# 9206                                         Usaquén  $ 580.000.000
# 6185                                         Usaquén  $ 449.500.000
# 2191              CHAPINERO: Pardo Rubio + Chapinero  $ 380.000.000
# 2461                                        Fontibón  $ 140.000.000
# 2752                                         Usaquén  $ 393.000.000
# 8108  PUENTE ARANDA: Zona Industrial + Puente Aranda  $ 600.000.000
# 4195                                    Bosa Central  $ 119.000.000
# 8157                                         Usaquén  $ 220.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles["Valor"][300]
# Out:
# '$ 116.100.000'

# %%
type (inmuebles["Valor"][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5076         Casa                Casa en venta en Teusaquillo             8
# 7416  Apartamento                Apartamento en venta en Bosa             2
# 5929  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 9063  Apartamento           Apartamento en venta en Chapinero             3
# 743          Casa              Casa en venta en Puente Aranda             5
# ...           ...                                         ...           ...
# 975          Casa         Casa en venta en Zona Noroccidental             4
# 5181  Apartamento                Apartamento en venta en Suba             3
# 1808  Apartamento           Apartamento en venta en Chapinero             3
# 7735  Apartamento            Apartamento en venta en Cedritos             3
# 8099  Apartamento     Apartamento en venta en Chico Reservado             1
#
#       Banos  Area              Barrio  \
# 5076      5   435         Teusaquillo
# 7416      1    43                Bosa
# 5929      2    88  Zona Noroccidental
# 9063      5   219           Chapinero
# 743       4   136       Puente Aranda
# ...     ...   ...                 ...
# 975       4   320  Zona Noroccidental
# 5181      1    53                Suba
# 1808      4   186           Chapinero
# 7735      4   130            Cedritos
# 8099      1    37     Chico Reservado
#
#                                                  UPZ            Valor
# 5076                                     Teusaquillo    $ 950.000.000
# 7416                                    Bosa Central    $ 112.000.000
# 5929              CHAPINERO: Pardo Rubio + Chapinero    $ 500.000.000
# 9063              CHAPINERO: Pardo Rubio + Chapinero  $ 1.200.000.000
# 743   PUENTE ARANDA: Zona Industrial + Puente Aranda    $ 400.000.000
# ...                                              ...              ...
# 975               CHAPINERO: Pardo Rubio + Chapinero  $ 1.300.000.000
# 5181                                            Suba    $ 140.000.000
# 1808              CHAPINERO: Pardo Rubio + Chapinero  $ 1.722.400.000
# 7735                                         Usaquén    $ 570.000.000
# 8099              CHAPINERO: Chicó Lago + El Refugio    $ 308.000.000
#
# [100 rows x 8 columns]

# %%
(inmuebles.Barrio == "Chico Reservado")
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == "Chico Reservado"))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == "Chico Reservado")
inmuebles_chico
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # Reto del aula 1

# %% [markdown]
# 1.Promedio de área de todos los inmubles en los barrios en dataset.El top 10

# %%
promedio_area = inmuebles.groupby('Barrio').Area.mean()
promedio_area
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# 2. Consultar otros datos estadisticos, conteo, mediana, valores minimos y máximo

# %%
promedio_habitaciones = inmuebles.groupby('Barrio').Habitaciones.mean()
promedio_habitaciones
# Out:
# Barrio
# Alameda               3.000000
# Alhambra              3.000000
# Andes Norte           3.000000
# Antonio Nariño        4.312500
# Barrancas             2.866667
#                         ...
# Villa Maria           4.692308
# Villas De Granada     3.454545
# Villemar              2.944444
# Zona Franca           2.000000
# Zona Noroccidental    3.167617
# Name: Habitaciones, Length: 149, dtype: float64

# %%
promedio_habitaciones.sort_values(ascending=False).head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# # Aula 2

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles["Moneda"] = valor [0]
inmuebles["Precio"] = valor [1]
inmuebles.sample(3)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8613  Apartamento  Apartamento en venta en Santa Barbara             1      2
# 3306  Apartamento        Apartamento en venta en Kennedy             3      1
# 1290  Apartamento        Apartamento en venta en Usaquén             4      5
#
#       Area         Barrio                                    UPZ  \
# 8613    66  Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 3306    49        Kennedy                        Kennedy Central
# 1290   330        Usaquén                                Usaquén
#
#                 Valor Moneda         Precio
# 8613    $ 453.500.000      $    453.500.000
# 3306    $ 149.000.000      $    149.000.000
# 1290  $ 4.200.000.000      $  4.200.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles["Precio"] = inmuebles["Precio"].str.replace(".","", regex=True)

# %%
inmuebles[["Precio","Barrio"]]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Transformar "tipo de dato" a un "tipo de dato numerico"
# Lo que se hace de un String a un tipo de dato numerico se tranforma a float

# %%
inmuebles ["Precio_Millon"] = inmuebles.Precio.astype("float")/ 1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# Eliminar posiones decimales

# %%
pd.set_option("display.precision", 2)
pd.set_option("display.float_format", lambda x: "%.2f" % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc [inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles["Precio_Millon"].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Grafica más detalladas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
sns.histplot(data=inmuebles, x="Precio_Millon")
plt.show()

# %% [markdown]
# Nombre de la grafica y limite de grafica maximo

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
grafica = sns.histplot(data=inmuebles, x="Precio_Millon")
grafica.set_title("Distribucion de valores de los inmuebles en Bogota")
plt.xlim((50,1000))
plt.show()

# %% [markdown]
# Grafica a través de una curva, para ver el comportamiento "curva de densidad"

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
grafica = sns.histplot(data=inmuebles, x="Precio_Millon", kde=True)
grafica.set_title("Distribucion de valores de los inmuebles en Bogota")
plt.xlim((50,1000))
plt.show()

# %% [markdown]
# Grfica de tipos de imuebles con (hue= "Tipo")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
grafica = sns.histplot(data=inmuebles, x="Precio_Millon", kde=True,hue="Tipo")
grafica.set_title("Distribucion de valores de los inmuebles en Bogota")
plt.xlim((50,1000))
plt.show()

# %% [markdown]
# # Reto del aula 2

# %% [markdown]
# Desafio 2
# Mejorar los histogrmas de valores, seleccionar 3 tipos de inmuebles (mejorar las grificas: titulo, coclusion)

# %% [markdown]
# tipos_seleccionados = inmuebles.Tipo = Casa
#                       inmuebles.Tipo = Oficina/Consultorio
#                       inmuebles.Tipo = Local

# %%
tipos_seleccionados = ((inmuebles.Tipo ==  'Casa') | 
                       (inmuebles.Tipo ==  'Oficina/Consultorio') |
                       (inmuebles.Tipo ==  'Local'))

plt.figure(figsize=(10,6))

grafica = sns.histplot(data = inmuebles[tipos_seleccionados], x = 'Precio_Millon',
                       edgecolor = "white",
                       linewidth = 2, 
                       kde = True, 
                       hue = 'Tipo')

grafica.set_title("Distribución de Valores de los inmuebles en Bogotá")

plt.xlim((50,1100))

plt.show()

# %% [markdown]
# El precio por metro por barrio con grafica

# %%
import matplotlib.pyplot as plt
import seaborn as sns

inmuebles['preciom2'] = inmuebles.Precio_Millon / inmuebles.Area

promedio_precio_m2_barrio = (inmuebles.groupby('Barrio')['preciom2']
                                 .mean()
                                 .reset_index()
                                 .sort_values('preciom2', ascending=False))

promedio_precio_m2_barrio.head(20).plot.bar('Barrio', 'preciom2');

# %%
inmuebles['metro_cuadrado'] = inmuebles['Precio_Millon'] / inmuebles['Area']
metro_cuadrado_barrio = inmuebles.groupby('Barrio')['metro_cuadrado'].mean().sort_values(ascending=False)
inmuebles.sample(10)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 3903  Apartamento     Apartamento en venta en San Patricio             3
# 1297  Apartamento        Apartamento en venta en Chapinero             3
# 5179  Apartamento      Apartamento en venta en Chico Norte             3
# 4346  Apartamento  Apartamento en venta en Chico Reservado             1
# 2030  Apartamento   Apartamento en venta en Barrios Unidos             2
# 3803  Apartamento          Apartamento en venta en El Plan             3
# 881   Apartamento      Apartamento en venta en Santa Paula             2
# 956   Apartamento       Apartamento en venta en La Calleja             3
# 1770  Apartamento         Apartamento en venta en Engativa             3
# 1970  Apartamento             Apartamento en venta en Suba             3
#
#       Banos  Area           Barrio                                    UPZ  \
# 3903      4   153     San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 1297      3   220        Chapinero     CHAPINERO: Pardo Rubio + Chapinero
# 5179      2   102      Chico Norte     CHAPINERO: Chicó Lago + El Refugio
# 4346      2    93  Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 2030      2    60   Barrios Unidos                              Los Andes
# 3803      2    86          El Plan                              El Rincón
# 881       3    85      Santa Paula  USAQUÉN: Country Club + Santa Bárbara
# 956       3   108       La Calleja  USAQUÉN: Country Club + Santa Bárbara
# 1770      2    75         Engativa                               Engativá
# 1970      2    62             Suba                                   Suba
#
#                 Valor Moneda      Precio  Precio_Millon  preciom2  \
# 3903    $ 990.000.000      $   990000000         990.00      6.47
# 1297  $ 1.800.000.000      $  1800000000        1800.00      8.18
# 5179    $ 800.000.000      $   800000000         800.00      7.84
# 4346    $ 872.000.000      $   872000000         872.00      9.38
# 2030    $ 340.000.000      $   340000000         340.00      5.67
# 3803    $ 550.000.000      $   550000000         550.00      6.40
# 881     $ 519.000.000      $   519000000         519.00      6.11
# 956     $ 620.000.000      $   620000000         620.00      5.74
# 1770    $ 409.365.000      $   409365000         409.37      5.46
# 1970    $ 185.000.000      $   185000000         185.00      2.98
#
#       metro_cuadrado
# 3903            6.47
# 1297            8.18
# 5179            7.84
# 4346            9.38
# 2030            5.67
# 3803            6.40
# 881             6.11
# 956             5.74
# 1770            5.46
# 1970            2.98

# %%
plt.figure(figsize=(15, 10))
grafica_barrio = sns.barplot(data=inmuebles, x='metro_cuadrado', y='Barrio', palette='dark')
grafica_barrio.set_title('Precio del Metro Cuadrado por Barrio')
grafica_barrio.set_xlabel('Metro Cuadrado')
grafica_barrio.set_ylabel('Barrio')
plt.xlim((1, 9))
plt.ylim((0, 20))
plt.show()

# %% [markdown]
# Gracias los dos gráficos generados es posible concluir que el barrio más caro es El Virrey ubicado en la zona norte de Bogotá, pues sus inmuebles en venta tienen en promedio un costo de 10 millones de Pesos Colombianos por metro cuadrado.
#
# Por otro lado, el barrio más barato es Bosa Piamonte ubicado en la zona occidental de Bogotá, con inmuebles en venta con un costo promedio de 1.2 millones de Pesos Colombianos por metro cuadrado.
#
# Finalmente, si se analiza la ubicación de los barrios mostrados en ambos gráficos, es posibles notar que los barrios más caros se ubican en la zona norte de Bogotá.

# %% [markdown]
# **Resolviendo reto en clase** Se resolvio de dos formas,
# Primero: Tomando como referencia, precio de todo nuestro data y dividirlo por la area.

# %% [markdown]
# # Aula 3

# %% [markdown]
# Vamos a crear una nueva columna que representa el calculo **"El valor por metro cuadrado"**

# %%
inmuebles["Valor_m2_Millon"] = inmuebles ["Precio_Millon"]/inmuebles["Area"]
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  preciom2  \
# 0    $ 360.000.000      $   360000000         360.00      5.14
# 1    $ 670.000.000      $   670000000         670.00      3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00      7.78
#
#    metro_cuadrado  valor_m2_Millon  Valor_m2_Millon
# 0            5.14             5.14             5.14
# 1            3.94             3.94             3.94
# 2            7.78             7.78             7.78

# %% [markdown]
# Aqui vamos agrupar los datos y los vamos agrupar en esta caso por barrio y vamos a tomar el promedio (En una agrupacion siempre se debe utilizar una funció de agregación)

# %%
inmuebles.groupby("Barrio").mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  preciom2  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00      5.98
# Alhambra                    3.00   2.94 190.41         752.35      4.33
# Andes Norte                 3.00   2.86 124.86         709.57      6.05
# Antonio Nariño              4.31   2.50 163.06         459.22      3.53
# Barrancas                   2.87   2.13  70.20         314.13      4.42
# ...                          ...    ...    ...            ...       ...
# Villa Maria                 4.69   3.69 207.15         402.85      2.04
# Villas De Granada           3.45   2.32  86.59         282.30      3.17
# Villemar                    2.94   2.06  76.89         303.83      3.99
# Zona Franca                 2.00   1.00  54.00         160.00      2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81      4.62
#
#                     metro_cuadrado  valor_m2_Millon  Valor_m2_Millon
# Barrio
# Alameda                       5.98             5.98             5.98
# Alhambra                      4.33             4.33             4.33
# Andes Norte                   6.05             6.05             6.05
# Antonio Nariño                3.53             3.53             3.53
# Barrancas                     4.42             4.42             4.42
# ...                            ...              ...              ...
# Villa Maria                   2.04             2.04             2.04
# Villas De Granada             3.17             3.17             3.17
# Villemar                      3.99             3.99             3.99
# Zona Franca                   2.96             2.96             2.96
# Zona Noroccidental            4.62             4.62             4.62
#
# [149 rows x 8 columns]

# %% [markdown]
# Vamos a agrupar por barrio pero en vez de aplicar directamente la funcion "mean" vamos a usar la función "sum" que es para sumar.

# %%
datos_barrio = inmuebles.groupby("Barrio").sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  preciom2  \
# Barrio
# Alameda                        3      2      97         580.00      5.98
# Alhambra                      51     50    3237       12790.00     73.56
# Andes Norte                   21     20     874        4967.00     42.35
# Antonio Nariño               207    120    7827       22042.65    169.47
# Barrancas                     43     32    1053        4712.00     66.24
# ...                          ...    ...     ...            ...       ...
# Villa Maria                   61     48    2693        5237.00     26.58
# Villas De Granada             76     51    1905        6210.62     69.71
# Villemar                      53     37    1384        5469.00     71.81
# Zona Franca                    2      1      54         160.00      2.96
# Zona Noroccidental          2778   2204  119084      544453.06   4049.16
#
#                     metro_cuadrado  valor_m2_Millon  Valor_m2_Millon
# Barrio
# Alameda                       5.98             5.98             5.98
# Alhambra                     73.56            73.56            73.56
# Andes Norte                  42.35            42.35            42.35
# Antonio Nariño              169.47           169.47           169.47
# Barrancas                    66.24            66.24            66.24
# ...                            ...              ...              ...
# Villa Maria                  26.58            26.58            26.58
# Villas De Granada            69.71            69.71            69.71
# Villemar                     71.81            71.81            71.81
# Zona Franca                   2.96             2.96             2.96
# Zona Noroccidental         4049.16          4049.16          4049.16
#
# [149 rows x 8 columns]

# %% [markdown]
# Vamos a calcular el promedio con base a la informacion anterior.

# %%
datos_barrio["Valor_m2_Barrio"] = datos_barrio["Precio_Millon"]/datos_barrio["Area"]
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  preciom2  \
# Barrio
# Alameda                        3      2      97         580.00      5.98
# Alhambra                      51     50    3237       12790.00     73.56
# Andes Norte                   21     20     874        4967.00     42.35
# Antonio Nariño               207    120    7827       22042.65    169.47
# Barrancas                     43     32    1053        4712.00     66.24
# ...                          ...    ...     ...            ...       ...
# Villa Maria                   61     48    2693        5237.00     26.58
# Villas De Granada             76     51    1905        6210.62     69.71
# Villemar                      53     37    1384        5469.00     71.81
# Zona Franca                    2      1      54         160.00      2.96
# Zona Noroccidental          2778   2204  119084      544453.06   4049.16
#
#                     metro_cuadrado  valor_m2_Millon  Valor_m2_Millon  \
# Barrio
# Alameda                       5.98             5.98             5.98
# Alhambra                     73.56            73.56            73.56
# Andes Norte                  42.35            42.35            42.35
# Antonio Nariño              169.47           169.47           169.47
# Barrancas                    66.24            66.24            66.24
# ...                            ...              ...              ...
# Villa Maria                  26.58            26.58            26.58
# Villas De Granada            69.71            69.71            69.71
# Villemar                     71.81            71.81            71.81
# Zona Franca                   2.96             2.96             2.96
# Zona Noroccidental         4049.16          4049.16          4049.16
#
#                     Valor_m2_Barrio
# Barrio
# Alameda                        5.98
# Alhambra                       3.95
# Andes Norte                    5.68
# Antonio Nariño                 2.82
# Barrancas                      4.47
# ...                             ...
# Villa Maria                    1.94
# Villas De Granada              3.26
# Villemar                       3.95
# Zona Franca                    2.96
# Zona Noroccidental             4.57
#
# [149 rows x 9 columns]

# %% [markdown]
# Aqui creamos un diccionario de datos de nuestro datos "Barrio" el Valor de precio por m2.

# %%
m2_barrio = dict(datos_barrio["Valor_m2_Barrio"])

# %%
inmuebles["Valor_m2_Barrio"] = inmuebles["Barrio"]
inmuebles["Valor_m2_Barrio"] = inmuebles["Valor_m2_Barrio"].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  preciom2  \
# 0    $ 360.000.000      $   360000000         360.00      5.14
# 1    $ 670.000.000      $   670000000         670.00      3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00      7.78
# 3    $ 890.000.000      $   890000000         890.00      5.78
# 4    $ 970.000.000      $   970000000         970.00      7.58
#
#    metro_cuadrado  valor_m2_Millon  Valor_m2_Millon  Valor_m2_Barrio
# 0            5.14             5.14             5.14             4.57
# 1            3.94             3.94             3.94             3.40
# 2            7.78             7.78             7.78             8.10
# 3            5.78             5.78             5.78             5.66
# 4            7.58             7.58             7.58             6.29

# %% [markdown]
# Aqui vamos a ver el top 10 de barrios que contienen más inmuebles a la venta.

# %%
top_barrios = inmuebles["Barrio"].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  preciom2  \
# 0               Alameda             3      2      97         580.00      5.98
# 1              Alhambra            51     50    3237       12790.00     73.56
# 2           Andes Norte            21     20     874        4967.00     42.35
# 3        Antonio Nariño           207    120    7827       22042.65    169.47
# 4             Barrancas            43     32    1053        4712.00     66.24
# ..                  ...           ...    ...     ...            ...       ...
# 144         Villa Maria            61     48    2693        5237.00     26.58
# 145   Villas De Granada            76     51    1905        6210.62     69.71
# 146            Villemar            53     37    1384        5469.00     71.81
# 147         Zona Franca             2      1      54         160.00      2.96
# 148  Zona Noroccidental          2778   2204  119084      544453.06   4049.16
#
#      metro_cuadrado  valor_m2_Millon  Valor_m2_Millon  Valor_m2_Barrio
# 0              5.98             5.98             5.98             5.98
# 1             73.56            73.56            73.56             3.95
# 2             42.35            42.35            42.35             5.68
# 3            169.47           169.47           169.47             2.82
# 4             66.24            66.24            66.24             4.47
# ..              ...              ...              ...              ...
# 144           26.58            26.58            26.58             1.94
# 145           69.71            69.71            69.71             3.26
# 146           71.81            71.81            71.81             3.95
# 147            2.96             2.96             2.96             2.96
# 148         4049.16          4049.16          4049.16             4.57
#
# [149 rows x 10 columns]

# %% [markdown]
# Podremos realizar consultas

# %%
datos_barrio.query("Barrio in @top_barrios")
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  preciom2  \
# 5        Barrios Unidos          1525   1196   87799      259877.76   2070.61
# 10                 Bosa          1743    789   34879       93400.56   1654.36
# 22             Cedritos          1458   1348   53711      270027.73   2853.23
# 24            Chapinero           892    913   81248      372130.93   2466.03
# 50             Engativa          1676   1077   59808      172711.73   1795.71
# 63              Kennedy          2151   1233   61475      207963.65   2127.66
# 125       Santa Barbara          1073   1162   54693      320097.80   2701.88
# 132                Suba          1497   1202   61615      266406.04   2000.72
# 138             Usaquén          3109   3044  148121      837710.36   6334.04
# 148  Zona Noroccidental          2778   2204  119084      544453.06   4049.16
#
#      metro_cuadrado  valor_m2_Millon  Valor_m2_Millon  Valor_m2_Barrio
# 5           2070.61          2070.61          2070.61             2.96
# 10          1654.36          1654.36          1654.36             2.68
# 22          2853.23          2853.23          2853.23             5.03
# 24          2466.03          2466.03          2466.03             4.58
# 50          1795.71          1795.71          1795.71             2.89
# 63          2127.66          2127.66          2127.66             3.38
# 125         2701.88          2701.88          2701.88             5.85
# 132         2000.72          2000.72          2000.72             4.32
# 138         6334.04          6334.04          6334.04             5.66
# 148         4049.16          4049.16          4049.16             4.57

# %% [markdown]
# Vamos a utilizar un    para resolver el desafio

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data = datos_barrio.query("Barrio in @top_barrios"))
ax.tick_params(axis="x",rotation=45)

# %% [markdown]
# Descripcion estadistica

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = datos_barrio.query("Barrio in @top_barrios"))
ax.tick_params(axis="x",rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Area', data = inmuebles.query('Barrio in @top_barrios & Area < 350'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon', data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()
